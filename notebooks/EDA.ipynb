# %% [markdown]
# # Introduction

# %%
import pandas as pd
import numpy as np

# %%
dictionary = pd.read_csv("../data/dictionary.csv")

# %%
dictionary
# Out:
#    Data Dictionary for CES4.0FINAL_results Data Spreadsheet  \
# 0                                       Variable Name
# 1                                        Census Tract
# 2                                    Total Population
# 3                                   California County
# 4                                                 ZIP
# ..                                                ...
# 71                                          White (%)
# 72                               African American (%)
# 73                                Native American (%)
# 74                                 Asian American (%)
# 75                                 Other/Multiple (%)
#
#                                            Unnamed: 1
# 0                                         Description
# 1                    Census Tract ID from 2010 Census
# 2     2019 ACS population estimates in census tracts
# 3   California county that the census tract falls ...
# 4   Postal ZIP Code that the census tract falls wi...
# ..                                                ...
# 71  2019 ACS population estimates of the percent p...
# 72  2019 ACS population estimates of the percent p...
# 73  2019 ACS population estimates of the percent p...
# 74  2019 ACS population estimates of the percent p...
# 75  2019 ACS population estimates of the percent p...
#
# [76 rows x 2 columns]

# %%
indicators = pd.read_csv("../data/indicators.csv")
demographics = pd.read_csv("../data/demographics.csv")

# %%
indicators.head()
# Out:
#    Census Tract  Total Population California County    ZIP  \
# 0    6019001100              2780           Fresno   93706
# 1    6077000700              4680       San Joaquin  95206
# 2    6037204920              2751       Los Angeles  90023
# 3    6019000700              3664           Fresno   93706
# 4    6019000200              2689           Fresno   93706
#
#   Approximate Location   Longitude   Latitude  CES 4.0 Score  \
# 0               Fresno -119.781696  36.709695          93.18
# 1             Stockton -121.287873  37.943173          86.65
# 2          Los Angeles -118.197497  34.017500          82.39
# 3               Fresno -119.827707  36.734535          81.33
# 4               Fresno -119.805504  36.735491          80.75
#
#     CES 4.0 Percentile  CES 4.0 Percentile Range  ...  \
# 0               100.00  95-100% (highest scores)  ...
# 1                99.99  95-100% (highest scores)  ...
# 2                99.97  95-100% (highest scores)  ...
# 3                99.96  95-100% (highest scores)  ...
# 4                99.95  95-100% (highest scores)  ...
#
#    Linguistic Isolation Pctl  Poverty  Poverty Pctl  Unemployment  \
# 0                      79.37     76.0         98.92          12.8
# 1                      95.53     73.2         98.39          19.8
# 2                      81.55     62.6         93.39           6.4
# 3                      78.71     65.7         95.35          15.7
# 4                      86.56     72.7         98.30          13.7
#
#    Unemployment Pctl  Housing Burden  Housing Burden Pctl  Pop. Char.   \
# 0              93.83            30.3                91.04        93.16
# 1              99.21            31.2                92.28        93.17
# 2              61.53            20.3                63.97        83.75
# 3              97.35            35.4                96.41        94.64
# 4              95.29            32.7                94.16        95.40
#
#    Pop. Char. Score  Pop. Char. Pctl
# 0              9.66            99.72
# 1              9.66            99.74
# 2              8.69            95.79
# 3              9.82            99.89
# 4              9.90            99.95
#
# [5 rows x 58 columns]

# %%
demographics.head()
# Out:
#   Demographic data (total population, age groups and race/ethnicity) by census tract were extracted from the 2019 American Community Survey.  \
# 0                                       Census Tract
# 1                                         6001400100
# 2                                         6001400200
# 3                                         6001400300
# 4                                         6001400400
#
#       Unnamed: 1          Unnamed: 2                Unnamed: 3  \
# 0  CES 4.0 Score  CES 4.0 Percentile  CES 4.0 Percentile Range
# 1           4.85                2.80      1-5% (lowest scores)
# 2           4.88                2.87      1-5% (lowest scores)
# 3          11.20               15.94                    15-20%
# 4          12.39               18.97                    15-20%
#
#           Unnamed: 4        Unnamed: 5               Unnamed: 6  \
# 0  California County  Total Population  Children < 10 years (%)
# 1           Alameda               3120                     7.82
# 2           Alameda               2007                    10.46
# 3           Alameda               5051                    11.42
# 4           Alameda               4007                     9.38
#
#             Unnamed: 7              Unnamed: 8    Unnamed: 9 Unnamed: 10  \
# 0  Pop 10-64 years (%)  Elderly > 64 years (%)  Hispanic (%)   White (%)
# 1                66.12                   26.06          3.78       74.26
# 2                66.32                   23.22          8.67       73.49
# 3                73.04                   15.54          6.95       67.99
# 4                78.79                   11.83          12.1       63.74
#
#             Unnamed: 11          Unnamed: 12         Unnamed: 13  \
# 0  African American (%)  Native American (%)  Asian American (%)
# 1                  3.43                    0               12.53
# 2                  2.59                  0.2                8.52
# 3                  9.09                    0               12.14
# 4                  6.64                 0.87               10.48
#
#           Unnamed: 14
# 0  Other/Multiple (%)
# 1                5.99
# 2                6.53
# 3                3.84
# 4                6.16
