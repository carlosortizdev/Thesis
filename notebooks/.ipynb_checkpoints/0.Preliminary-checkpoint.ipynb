# %% [markdown]
# # Preliminary

# %%
import pandas as pd
import numpy as np
import statsmodels
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Data

# %%
la_county = pd.read_csv("../data/la-county.csv")
la_county
# Out:
#                 City  Date incorporated Population as of(2020 Census)
# 0       Agoura Hills   December 8, 1982                        20,299
# 1           Alhambra      July 11, 1903                        82,868
# 2            Arcadia     August 5, 1903                        56,681
# 3            Artesia       May 29, 1959                        16,395
# 4             Avalon      June 26, 1913                         3,460
# ..               ...                ...                           ...
# 83            Walnut   January 19, 1959                        28,430
# 84       West Covina  February 17, 1923                       109,501
# 85    West Hollywood  November 29, 1984                        35,757
# 86  Westlake Village  December 11, 1981                         8,029
# 87          Whittier  February 28, 1898                        87,306
#
# [88 rows x 3 columns]

# %%
la_county = list(la_county['City'])

# %% [markdown]
# ### CalEPA - Demographics + Indicators

# %%
epa_indicators = pd.read_csv("../data/CalEPA/indicators.csv")
epa_demographics = pd.read_csv("../data/CalEPA/demographics.csv")

# %%
epa_indicators
# Out:
#       Census Tract  Total Population California County    ZIP  \
# 0       6019001100              2780           Fresno   93706
# 1       6077000700              4680       San Joaquin  95206
# 2       6037204920              2751       Los Angeles  90023
# 3       6019000700              3664           Fresno   93706
# 4       6019000200              2689           Fresno   93706
# ...            ...               ...               ...    ...
# 8030    6107004000               582           Tulare   93257
# 8031    6109985202              2509         Tuolumne   95327
# 8032    6111001206               778          Ventura   93001
# 8033    6111003012               675          Ventura   93036
# 8034    6111980000               118          Ventura      61
#
#                      Approximate Location   Longitude   Latitude  \
# 0                                  Fresno -119.781696  36.709695
# 1                                Stockton -121.287873  37.943173
# 2                             Los Angeles -118.197497  34.017500
# 3                                  Fresno -119.827707  36.734535
# 4                                  Fresno -119.805504  36.735491
# ...                                   ...         ...        ...
# 8030                          Porterville -118.983849  36.038061
# 8031  Unincorporated Tuolumne County area -120.537071  37.891939
# 8032   Unincorporated Ventura County area -119.371944  34.343903
# 8033                               Oxnard -119.180105  34.235076
# 8034   Unincorporated Ventura County area -119.503588  33.255655
#
#       CES 4.0 Score   CES 4.0 Percentile  CES 4.0 Percentile Range  ...  \
# 0             93.18               100.00  95-100% (highest scores)  ...
# 1             86.65                99.99  95-100% (highest scores)  ...
# 2             82.39                99.97  95-100% (highest scores)  ...
# 3             81.33                99.96  95-100% (highest scores)  ...
# 4             80.75                99.95  95-100% (highest scores)  ...
# ...             ...                  ...                       ...  ...
# 8030            NaN                  NaN                       NaN  ...
# 8031            NaN                  NaN                       NaN  ...
# 8032            NaN                  NaN                       NaN  ...
# 8033            NaN                  NaN                       NaN  ...
# 8034            NaN                  NaN                       NaN  ...
#
#       Linguistic Isolation Pctl  Poverty  Poverty Pctl  Unemployment  \
# 0                         79.37     76.0         98.92          12.8
# 1                         95.53     73.2         98.39          19.8
# 2                         81.55     62.6         93.39           6.4
# 3                         78.71     65.7         95.35          15.7
# 4                         86.56     72.7         98.30          13.7
# ...                         ...      ...           ...           ...
# 8030                        NaN     79.6         99.42           NaN
# 8031                        NaN      NaN           NaN           NaN
# 8032                        NaN     17.1         27.35           NaN
# 8033                      99.55     96.7        100.00           NaN
# 8034                        NaN      NaN           NaN           NaN
#
#       Unemployment Pctl  Housing Burden  Housing Burden Pctl  Pop. Char.   \
# 0                 93.83            30.3                91.04        93.16
# 1                 99.21            31.2                92.28        93.17
# 2                 61.53            20.3                63.97        83.75
# 3                 97.35            35.4                96.41        94.64
# 4                 95.29            32.7                94.16        95.40
# ...                 ...             ...                  ...          ...
# 8030                NaN             NaN                  NaN          NaN
# 8031                NaN             NaN                  NaN          NaN
# 8032                NaN            24.4                78.47          NaN
# 8033                NaN             NaN                  NaN          NaN
# 8034                NaN             NaN                  NaN          NaN
#
#       Pop. Char. Score  Pop. Char. Pctl
# 0                 9.66            99.72
# 1                 9.66            99.74
# 2                 8.69            95.79
# 3                 9.82            99.89
# 4                 9.90            99.95
# ...                ...              ...
# 8030               NaN              NaN
# 8031               NaN              NaN
# 8032               NaN              NaN
# 8033               NaN              NaN
# 8034               NaN              NaN
#
# [8035 rows x 58 columns]

# %%
epa_demographics
# Out:
#       Census Tract  CES 4.0 Score  CES 4.0 Percentile  \
# 0       6001400100           4.85                2.80
# 1       6001400200           4.88                2.87
# 2       6001400300          11.20               15.94
# 3       6001400400          12.39               18.97
# 4       6001400500          16.73               29.74
# ...            ...            ...                 ...
# 8030    6115040800          21.59               41.28
# 8031    6115040901          30.21               59.13
# 8032    6115040902          18.67               34.43
# 8033    6115041000          21.99               42.13
# 8034    6115041100          11.69               17.01
#
#      CES 4.0 Percentile Range California County  Total Population  \
# 0        1-5% (lowest scores)          Alameda               3120
# 1        1-5% (lowest scores)          Alameda               2007
# 2                      15-20%          Alameda               5051
# 3                      15-20%          Alameda               4007
# 4                      25-30%          Alameda               4124
# ...                       ...               ...               ...
# 8030                   40-45%             Yuba               4652
# 8031                   55-60%             Yuba               2720
# 8032                   30-35%             Yuba               1653
# 8033                   40-45%             Yuba               7298
# 8034                   15-20%             Yuba               4122
#
#       Children < 10 years (%)  Pop 10-64 years (%)  Elderly > 64 years (%)  \
# 0                        7.82                66.12                   26.06
# 1                       10.46                66.32                   23.22
# 2                       11.42                73.04                   15.54
# 3                        9.38                78.79                   11.83
# 4                        9.12                81.96                    8.92
# ...                       ...                  ...                     ...
# 8030                    10.00                76.01                   13.99
# 8031                    13.68                65.63                   20.70
# 8032                    14.46                85.54                    0.00
# 8033                    15.26                63.07                   21.66
# 8034                     7.76                61.79                   30.45
#
#       Hispanic (%)  White (%)  African American (%)  Native American (%)  \
# 0             3.78      74.26                  3.43                 0.00
# 1             8.67      73.49                  2.59                 0.20
# 2             6.95      67.99                  9.09                 0.00
# 3            12.10      63.74                  6.64                 0.87
# 4             9.46      45.44                 21.39                 0.00
# ...            ...        ...                   ...                  ...
# 8030         15.82      75.06                  0.15                 0.99
# 8031         17.50      63.42                  0.74                 1.10
# 8032         19.78      56.38                  8.59                 0.18
# 8033         12.89      77.87                  4.03                 0.08
# 8034          9.49      79.14                  3.01                 0.97
#
#       Asian American (%)  Other/Multiple (%)
# 0                  12.53                5.99
# 1                   8.52                6.53
# 2                  12.14                3.84
# 3                  10.48                6.16
# 4                  11.34               12.37
# ...                  ...                 ...
# 8030                2.60                5.37
# 8031               10.40                6.84
# 8032                8.47                6.59
# 8033                2.14                2.99
# 8034                0.41                6.99
#
# [8035 rows x 15 columns]

# %% [markdown]
# Remove duplicate columns between indicators and demographics

# %%
duplicates = ['Total Population', 'California County', 'CES 4.0 Score', 'CES 4.0 Percentile Range']

# %%
epa_demographics = epa_demographics.drop(duplicates, axis=1)

# %% [markdown]
# Take LA county cities

# %%
la_indicators = epa_indicators[epa_indicators['California County'] == 'Los Angeles']

# %%
la_county_df = la_indicators.merge(epa_demographics, on='Census Tract', how='inner')

# %%
la_county_df = la_county_df.drop([' CES 4.0 Percentile'], axis=1)

# %%
la_county_df
# Out:
#       Census Tract  Total Population California County    ZIP  \
# 0       6037204920              2751       Los Angeles  90023
# 1       6037542402              3306       Los Angeles  90221
# 2       6037543202              5124       Los Angeles  90220
# 3       6037203300              2000       Los Angeles  90033
# 4       6037291220              3640       Los Angeles  90247
# ...            ...               ...               ...    ...
# 2338    6037980026                26       Los Angeles  91042
# 2339    6037980028                 0       Los Angeles  90045
# 2340    6037980030                 0       Los Angeles  90245
# 2341    6037980031              1175       Los Angeles  90731
# 2342    6037980033                16       Los Angeles  90802
#
#      Approximate Location   Longitude   Latitude  CES 4.0 Score  \
# 0             Los Angeles -118.197497  34.017500          82.39
# 1                 Compton -118.212413  33.881969          80.71
# 2                 Compton -118.230032  33.879862          79.29
# 3             Los Angeles -118.207788  34.058872          77.35
# 4             Los Angeles -118.286709  33.877139          77.25
# ...                   ...         ...        ...            ...
# 2338          Los Angeles -118.263309  34.273483            NaN
# 2339          Los Angeles -118.417488  33.942108            NaN
# 2340           El Segundo -118.409478  33.909624            NaN
# 2341          Los Angeles -118.262727  33.733835            NaN
# 2342           Long Beach -118.220310  33.744315            NaN
#
#       CES 4.0 Percentile Range  Ozone  ...  CES 4.0 Percentile  \
# 0     95-100% (highest scores)  0.048  ...               99.97
# 1     95-100% (highest scores)  0.043  ...               99.94
# 2     95-100% (highest scores)  0.042  ...               99.91
# 3     95-100% (highest scores)  0.049  ...               99.87
# 4     95-100% (highest scores)  0.041  ...               99.86
# ...                        ...    ...  ...                 ...
# 2338                       NaN  0.066  ...                 NaN
# 2339                       NaN  0.043  ...                 NaN
# 2340                       NaN  0.043  ...                 NaN
# 2341                       NaN  0.038  ...                 NaN
# 2342                       NaN  0.039  ...                 NaN
#
#       Children < 10 years (%)  Pop 10-64 years (%)  Elderly > 64 years (%)  \
# 0                       13.34                72.59                   14.07
# 1                       11.34                77.53                   11.13
# 2                       18.60                72.48                    8.92
# 3                        7.70                84.50                    7.80
# 4                       12.77                73.16                   14.07
# ...                       ...                  ...                     ...
# 2338                     0.00               100.00                    0.00
# 2339                      NaN                  NaN                     NaN
# 2340                      NaN                  NaN                     NaN
# 2341                     1.70                88.60                    9.70
# 2342                     0.00                 0.00                  100.00
#
#       Hispanic (%)  White (%)  African American (%)  Native American (%)  \
# 0            97.27       1.71                  0.84                 0.00
# 1            65.34       0.54                 33.55                 0.00
# 2            78.14       1.09                 15.67                 0.00
# 3            75.55       2.85                 10.45                 0.00
# 4            69.34       3.98                  8.43                 0.00
# ...            ...        ...                   ...                  ...
# 2338         26.92      26.92                 42.31                 0.00
# 2339           NaN        NaN                   NaN                  NaN
# 2340           NaN        NaN                   NaN                  NaN
# 2341         32.94      33.45                 19.74                 2.21
# 2342          0.00       0.00                  0.00               100.00
#
#       Asian American (%)  Other/Multiple (%)
# 0                   0.00                0.18
# 1                   0.57                0.00
# 2                   4.84                0.25
# 3                   6.95                4.20
# 4                  16.32                1.92
# ...                  ...                 ...
# 2338                0.00                3.85
# 2339                 NaN                 NaN
# 2340                 NaN                 NaN
# 2341                5.10                6.55
# 2342                0.00                0.00
#
# [2343 rows x 67 columns]

# %% [markdown]
# Available features:

# %%
la_county_df.columns
# Out:
# Index(['Census Tract', 'Total Population', 'California County', 'ZIP',
#        'Approximate Location', 'Longitude', 'Latitude', 'CES 4.0 Score',
#        'CES 4.0 Percentile Range', 'Ozone', 'Ozone Pctl', 'PM2.5',
#        'PM2.5 Pctl', 'Diesel PM', 'Diesel PM Pctl', 'Drinking Water',
#        'Drinking Water Pctl', 'Lead', 'Lead Pctl', 'Pesticides',
#        'Pesticides Pctl', 'Tox. Release', 'Tox. Release Pctl', 'Traffic',
#        'Traffic Pctl', 'Cleanup Sites', 'Cleanup Sites Pctl',
#        'Groundwater Threats', 'Groundwater Threats Pctl', 'Haz. Waste',
#        'Haz. Waste Pctl', 'Imp. Water Bodies', 'Imp. Water Bodies Pctl',
#        'Solid Waste', 'Solid Waste Pctl', 'Pollution Burden',
#        'Pollution Burden Score', 'Pollution Burden Pctl', 'Asthma',
#        'Asthma Pctl', 'Low Birth Weight', 'Low Birth Weight Pctl',
#        'Cardiovascular Disease', 'Cardiovascular Disease Pctl', 'Education',
#        'Education Pctl', 'Linguistic Isolation', 'Linguistic Isolation Pctl',
#        'Poverty', 'Poverty Pctl', 'Unemployment', 'Unemployment Pctl',
#        'Housing Burden', 'Housing Burden Pctl', 'Pop. Char. ',
#        'Pop. Char. Score', 'Pop. Char. Pctl', 'CES 4.0 Percentile',
#        'Children < 10 years (%)', 'Pop 10-64 years (%)',
#        'Elderly > 64 years (%)', 'Hispanic (%)', 'White (%)',
#        'African American (%)', 'Native American (%)', 'Asian American (%)',
#        'Other/Multiple (%)'],
#       dtype='object')

# %%
la_county_df["CES 4.0 Percentile Range"].unique()
# Out:
# array(['95-100% (highest scores)', '90-95%', '85-90%', '80-85%', '75-80%',
#        '70-75%', '65-70%', '60-65%', '55-60%', '50-55%', '45-50%',
#        '40-45%', '35-40%', '30-35%', '25-30%', '20-25%', '15-20%',
#        '10-15%', '5-10%', '1-5% (lowest scores)', nan], dtype=object)

# %% [markdown]
# ## Intitial Distributions

# %% [markdown]
# Let's take a look at some initiatial distributions before subseting the data further.

# %%
sns.histplot(la_county_df, x='Pollution Burden', stat='density')
# Out:
# <AxesSubplot:xlabel='Pollution Burden', ylabel='Density'>

# %%
sns.histplot(la_county_df, x='Traffic', stat='density')
# Out:
# <AxesSubplot:xlabel='Traffic', ylabel='Density'>

# %% [markdown]
# ## Subset Distribtuions

# %% [markdown]
# Now let's take a look at the distributions for the data with a CES 4.0 score above 95%.

# %%
highest_95_100 = la_county_df[la_county_df['CES 4.0 Percentile Range'] == '95-100% (highest scores)']

# %% [markdown]
# Let's take a look at the highest percentile range for the CES 4.0 score: 95-100%

# %%
highest_95_100
# Out:
#      Census Tract  Total Population California County    ZIP  \
# 0      6037204920              2751       Los Angeles  90023
# 1      6037542402              3306       Los Angeles  90221
# 2      6037543202              5124       Los Angeles  90220
# 3      6037203300              2000       Los Angeles  90033
# 4      6037291220              3640       Los Angeles  90247
# ..            ...               ...               ...    ...
# 275    6037104822              2839       Los Angeles  91331
# 276    6037104403              3341       Los Angeles  91331
# 277    6037433401              3405       Los Angeles  91733
# 278    6037294820              3473       Los Angeles  90744
# 279    6037553601              4699       Los Angeles  90723
#
#     Approximate Location   Longitude   Latitude  CES 4.0 Score  \
# 0            Los Angeles -118.197497  34.017500          82.39
# 1                Compton -118.212413  33.881969          80.71
# 2                Compton -118.230032  33.879862          79.29
# 3            Los Angeles -118.207788  34.058872          77.35
# 4            Los Angeles -118.286709  33.877139          77.25
# ..                   ...         ...        ...            ...
# 275          Los Angeles -118.420924  34.245834          58.96
# 276          Los Angeles -118.434485  34.258774          58.90
# 277             El Monte -118.042612  34.059602          58.86
# 278          Los Angeles -118.265626  33.779782          58.86
# 279            Paramount -118.169223  33.904663          58.81
#
#      CES 4.0 Percentile Range  Ozone  ...  CES 4.0 Percentile  \
# 0    95-100% (highest scores)  0.048  ...               99.97
# 1    95-100% (highest scores)  0.043  ...               99.94
# 2    95-100% (highest scores)  0.042  ...               99.91
# 3    95-100% (highest scores)  0.049  ...               99.87
# 4    95-100% (highest scores)  0.041  ...               99.86
# ..                        ...    ...  ...                 ...
# 275  95-100% (highest scores)  0.067  ...               95.08
# 276  95-100% (highest scores)  0.067  ...               95.06
# 277  95-100% (highest scores)  0.056  ...               95.03
# 278  95-100% (highest scores)  0.039  ...               95.02
# 279  95-100% (highest scores)  0.044  ...               95.01
#
#      Children < 10 years (%)  Pop 10-64 years (%)  Elderly > 64 years (%)  \
# 0                      13.34                72.59                   14.07
# 1                      11.34                77.53                   11.13
# 2                      18.60                72.48                    8.92
# 3                       7.70                84.50                    7.80
# 4                      12.77                73.16                   14.07
# ..                       ...                  ...                     ...
# 275                    16.10                75.31                    8.59
# 276                    11.40                75.46                   13.14
# 277                    11.54                78.27                   10.19
# 278                    20.79                72.79                    6.42
# 279                    11.83                78.83                    9.34
#
#      Hispanic (%)  White (%)  African American (%)  Native American (%)  \
# 0           97.27       1.71                  0.84                  0.0
# 1           65.34       0.54                 33.55                  0.0
# 2           78.14       1.09                 15.67                  0.0
# 3           75.55       2.85                 10.45                  0.0
# 4           69.34       3.98                  8.43                  0.0
# ..            ...        ...                   ...                  ...
# 275         90.63       2.40                  1.23                  0.0
# 276         95.51       0.45                  0.00                  0.0
# 277         69.81       2.26                  0.35                  0.0
# 278         96.69       0.75                  0.89                  0.0
# 279         85.74       3.81                  4.94                  0.0
#
#      Asian American (%)  Other/Multiple (%)
# 0                  0.00                0.18
# 1                  0.57                0.00
# 2                  4.84                0.25
# 3                  6.95                4.20
# 4                 16.32                1.92
# ..                  ...                 ...
# 275                5.00                0.74
# 276                4.04                0.00
# 277               27.20                0.38
# 278                1.67                0.00
# 279                4.81                0.70
#
# [280 rows x 67 columns]

# %%
sns.histplot(highest_95_100, x='Pollution Burden', stat='density')
# Out:
# <AxesSubplot:xlabel='Pollution Burden', ylabel='Density'>

# %%
sns.histplot(highest_95_100, x='Traffic', stat='density')
# Out:
# <AxesSubplot:xlabel='Traffic', ylabel='Density'>
